# %% [markdown]
# <a href="https://colab.research.google.com/github/jcmachicao/MachineLearningAvanzado_UC_2024/blob/main/practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Práctica de Modelamniento de Red Neuronal: Regresión

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

# Cargar el conjunto de datos de California Housing
housing = fetch_california_housing()

# Convertir los datos a un DataFrame de pandas
df = pd.DataFrame(data=housing.data, columns=housing.feature_names)
df['target'] = housing.target

# %%
df.shape
# Out:
# (20640, 9)

# %%
df.target.plot()
# Out:
# <Axes: >

# %%
df.target.hist(bins=50)
# Out:
# <Axes: >

# %%
# Mostrar las primeras filas del DataFrame
print(df.head())
