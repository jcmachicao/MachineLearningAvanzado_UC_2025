# %% [markdown]
# <a href="https://colab.research.google.com/github/jcmachicao/MachineLearningAvanzado_UC_2025/blob/main/U3__arquitecturas_cognitivas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vinculaciones entre Arquitecturas de Deep Learning y Funciones Cognitivas

# %% [markdown]
# ![Screenshot 2025-01-24 232605.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2025-01-24 224130.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [Red de Vinculación entre Arquitecturas DL y funciones cognitivas](https://kumu.io/jcmachicao/arquitecturas-deeplearning#redprincipal)
